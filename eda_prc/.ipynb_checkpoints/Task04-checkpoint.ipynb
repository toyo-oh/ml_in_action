# %% [markdown]
# ## 第二章 数据可视化 ##

# %% [markdown]
# ### 7.1导入 ###

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt## 第二章 数据重构##

# %%
text = pd.read_csv('data/result.csv')
text.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0    1.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                             Heikkinen, Miss. Laina  female  26.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                           Allen, Mr. William Henry    male  35.0    0.0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0    0.0         A/5 21171   7.2500   NaN        S
# 1    0.0          PC 17599  71.2833   C85        C
# 2    0.0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# ### 7.2数据可视化 ###

# %%
#7.2.1 了解matplotlib,创建一个数据项，对其进行可视化操作

# %% [markdown]
# 折线图：常用于表示前后变化，对比，趋势信息
# 条形图：对比，高低差距
# 直方图：表现单独的维度信息
# 箱线图：上边界，上四分位，中位数，下四分位，下边界
# 散点图：体现相关程度
# 饼状图：查看百分比

# %%
#7.2.2泰坦尼克号数据中男女生存人数分布状况
sex_group = text.groupby(['Sex'])['Survived'].sum()
sex_group
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
sex_group.plot.bar()
plt.title('survived_count')
plt.show()

# %%
#  7.2.3泰坦尼克号数据中男女生存与死亡人数比例
sex_survived = text.groupby(['Sex','Survived'])['Survived'].count()
sex_survived
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
sex_survived = sex_survived.unstack()
sex_survived
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
sex_survived.plot(kind='bar',stacked=True)
plt.title('survived_count')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
#7.2.4 不同票价的人生存和死亡人数分布情况
fare_survived = text.groupby(['Fare'])['Survived'].value_counts().sort_values(ascending=False)
fare_survived
# Out:
# Fare     Survived
# 8.0500   0           38
# 7.8958   0           37
# 13.0000  0           26
# 7.7500   0           22
# 26.0000  0           16
#                      ..
# 20.2500  1            1
#          0            1
# 18.7875  1            1
#          0            1
# 15.0500  0            1
# Name: Survived, Length: 330, dtype: int64

# %%
fig = plt.figure(figsize=(20, 18)) 
fare_survived.plot(grid=True) 
plt.legend()

# %%
fare_survived = text.groupby(['Fare'])['Survived'].value_counts()
fare_survived
# Out:
# Fare      Survived
# 0.0000    0           14
#           1            1
# 4.0125    0            1
# 5.0000    0            1
# 6.2375    0            1
#                       ..
# 247.5208  1            1
# 262.3750  1            2
# 263.0000  0            2
#           1            2
# 512.3292  1            3
# Name: Survived, Length: 330, dtype: int64

# %%
fig = plt.figure(figsize=(20, 18)) 
fare_survived.plot(grid=True) 
plt.legend()

# %%
#7.2.5不同仓位的人生存和死亡人数分布情况
import seaborn as sns
sns.countplot(x="Pclass", hue="Survived", data=text)

# %%
#不同年龄的人生存和死亡人数分布情况
facet = sns.FacetGrid(text, hue="Survived",aspect=3)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, text['Age'].max()))
facet.add_legend()

# %%
#不同仓位的等级的人年龄分布状况
text.Age[text.Pclass == 1].plot(kind='kde')
text.Age[text.Pclass == 2].plot(kind='kde')
text.Age[text.Pclass == 3].plot(kind='kde')
plt.xlabel("age")
plt.legend((1,2,3),loc="best")
